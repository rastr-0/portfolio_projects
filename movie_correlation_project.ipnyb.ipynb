# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10, 6)

# %%
#Read the data and have at it quick look
df = pd.read_csv(r'C:\Users\rastr\Downloads\archive\movies.csv')
df.head(3)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
#
#          gross            company  runtime
# 0   46998772.0       Warner Bros.    146.0
# ...

# %%
#Check if there is any Outliers
df.boxplot(column=['gross'], figsize=(8, 8))
# Out:
# <AxesSubplot: >

# %%
#Check if there is any missing data
for col in df.columns:
    percent_missing = np.mean(df[col].isnull())
    print('{} - {:.2f}%'.format(col, percent_missing))
# Out:
# name - 0.00%
# rating - 0.01%
# genre - 0.00%
# year - 0.00%
# released - 0.00%
# score - 0.00%
# votes - 0.00%
# director - 0.00%
# writer - 0.00%
# star - 0.00%
# country - 0.00%
# budget - 0.28%
# gross - 0.02%
# company - 0.00%
# runtime - 0.00%

# %%
#Data types for columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
#              ...
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# Length: 15, dtype: object

# %%
#Drop all NA values
df = df.dropna()

# %%
#Extract year from the "released" column and add year to new "yearcorrect" column
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)

# %%
#Sort values
pd.set_option('display.max_rows', 10)
df = df.sort_values(by=['gross'], inplace=False, ascending=False)

# %%
#Drop any duplicates
df.drop_duplicates()
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %% [markdown]
# #### Things, which might have **high** correlation with gross in my mind:
# * budget
# * director
# * company

# %%
#Scatter plot with budget & gross
plt.scatter(x=df['budget'], y=df['gross'], color='#89ABE3FF')

plt.title('Budget vs Gross Earnings', fontdict={'fontsize':20}, pad=20)
plt.xlabel('Gross', labelpad=15)
plt.ylabel('Budget', labelpad=15)

plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
#Plot budget vs gross using seaborn
sns.set(rc={'figure.figsize':(10,8)})
sns.regplot(x='budget', y='gross', data=df, scatter_kws={'color':'#89ABE3FF'}, line_kws={'color':'#EA738DFF'})
plt.title('Budget vs Gross Earnings', fontdict={'fontsize':20}, pad=20)
plt.xlabel('Gross')
plt.ylabel('Budget')
plt.show()

# %%
#Looking more detailed at correlation
df.corr(numeric_only=True, method='pearson')
# Out:
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# year            0.998726
# score           0.061923
# votes           0.203098
# budget          0.320312
# gross           0.268721
# runtime         0.075294
# yearcorrect     1.000000

# %%
#Visualization of correlation between gross and budget
correlation_matrix = df.corr(numeric_only=True, method='pearson')

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation MatrIx for Numeric Features', fontdict={'fontsize':20}, pad=20)
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Looks at Company
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
#Transform all object types into category type and give it codes for doing correlation map
df_numerized = df

for col in df_numerized.columns:
    if(df_numerized[col].dtype == 'object'):
        df_numerized[col] = df_numerized[col].astype('category')
        df_numerized[col] = df_numerized[col].cat.codes

df_numerized
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   386       5      0  2009       527    7.8  1100000.0       785    1263
# 7445   388       5      0  2019       137    8.4   903000.0       105     513
# 3045  4909       5      6  1997       534    7.8  1100000.0       785    1263
# 6663  3643       5      0  2015       529    7.8   876000.0       768    1806
# 7244   389       5      0  2018       145    8.4   897000.0       105     513
# ...    ...     ...    ...   ...       ...    ...        ...       ...     ...
# 5640  3794       6      6  2009       890    5.8     3500.0       585    2924
# 2434  2969       5      0  1993      1467    4.5     1900.0      1805    3102
# 3681  1595       3      6  2000      1721    6.8    43000.0       952    1683
# 272   2909       6      9  1982      1525    3.9     2300.0       261      55
# 3203  4966       5      4  1997      2152    5.7     5800.0       651     161
#
# ...

# %%
#Visualization of correlation between every column
correlation_matrix = df_numerized.corr(numeric_only=True, method='pearson')

sns.set(rc={'figure.figsize':(15,7)})

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation MatrIx for NotNumeric Features', fontdict={'fontsize':20}, pad=20)
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
#Find columns, which correlate the most with each others
correlation_matrix = df_numerized.corr()

corr_pairs = correlation_matrix.unstack()
sorted_pairs = corr_pairs.sort_values(ascending=False)
sorted_pairs.drop_duplicates()
sorted_pairs[(sorted_pairs > 0.5) & (sorted_pairs < 0.99)]
# Out:
# budget  gross     0.740247
# gross   budget    0.740247
#         votes     0.614751
# votes   gross     0.614751
# dtype: float64

# %% [markdown]
# So, in the result we can see that **budget & gross** and **votes & gross** have the biggest correlation between each other
